# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd

read_file = pd.read_csv (r'/content/iris.data')
read_file.to_csv (r'iris.csv', index=None)

# %% [markdown]
# ![2.jpg](data:image/jpeg;base64,...)

# %%
df = pd.read_csv('/content/iris.csv')
column_names=['sepal_length','sepal_width','petal length','petal width','class']
df.columns = column_names
df.head()
# Out:
#    sepal_length  sepal_width  petal length  petal width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %%
  
#Independent Variables
x = df[['sepal_length','sepal_width','petal length','petal width']]

#Dependent Variable
y = df['class']
  
# Splitting the dataset into training and test set.  
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.25, random_state=0)  
  
#feature Scaling  
from sklearn.preprocessing import StandardScaler    
st_x= StandardScaler()    
x_train= st_x.fit_transform(x_train)    
x_test= st_x.transform(x_test)

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %%
 
from sklearn.neighbors import KNeighborsClassifier  
classifier= KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2 )  
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score
#Predicting the test set result  
y_pred= classifier.predict(x_test)  
test_acc = accuracy_score(y_test,y_pred)
print("Accuracy on Testing dataset : ",round(test_acc,3))
# Out:
# Accuracy on Testing dataset :  0.868

# %%
# calculating other classification metrics
print(classification_report(y_pred,y_test,target_names=["Iris Setosa","Iris Versicolour","Iris Virginica"]))
# Out:
#                   precision    recall  f1-score   support
#
#      Iris Setosa       1.00      1.00      1.00        14
# Iris Versicolour       0.93      0.76      0.84        17
#   Iris Virginica       0.60      0.86      0.71         7
#
#         accuracy                           0.87        38
#        macro avg       0.84      0.87      0.85        38
#     weighted avg       0.89      0.87      0.87        38

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth=7)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=7)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
y_pred_test = rf.predict(x_test)
test_acc1 = accuracy_score(y_test,y_pred_test)
print("Accuracy on Testing dataset : ",round(test_acc1,3))
# Out:
# Accuracy on Testing dataset :  0.868

# %%
# calculating other classification metrics
print(classification_report(y_pred_test,y_test,target_names=["Iris Setosa","Iris Versicolour","Iris Virginica"]))
# Out:
#                   precision    recall  f1-score   support
#
#      Iris Setosa       1.00      1.00      1.00        14
# Iris Versicolour       0.93      0.76      0.84        17
#   Iris Virginica       0.60      0.86      0.71         7
#
#         accuracy                           0.87        38
#        macro avg       0.84      0.87      0.85        38
#     weighted avg       0.89      0.87      0.87        38

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %%
from sklearn.naive_bayes import BernoulliNB
clf = BernoulliNB()
clf.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
naive_predict=clf.predict(x_test)
test_acc2 = accuracy_score(y_test,naive_predict)
print("Accuracy on Testing dataset : ",round(test_acc2,3))
# Out:
# Accuracy on Testing dataset :  0.711

# %%
# calculating other classification metrics
print(classification_report(naive_predict,y_test,target_names=["Iris Setosa","Iris Versicolour","Iris Virginica"]))
# Out:
#                   precision    recall  f1-score   support
#
#      Iris Setosa       1.00      0.82      0.90        17
# Iris Versicolour       0.29      0.80      0.42         5
#   Iris Virginica       0.90      0.56      0.69        16
#
#         accuracy                           0.71        38
#        macro avg       0.73      0.73      0.67        38
#     weighted avg       0.86      0.71      0.75        38
